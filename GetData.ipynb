# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', 200)

#Visualization packages
import matplotlib.pyplot as plt
import seaborn as sns

#NLP packages
from textblob import TextBlob

import warnings
warnings.filterwarnings("ignore")

# %%
TextBlob("Power is the disease.  Care is the cure.  Keep caring for yourself and others as best as you can.  This is life.	").sentiment
# Out:
# Sentiment(polarity=1.0, subjectivity=0.3)

# %%
comm = pd.read_csv('ALLcomments.csv',encoding='utf8',error_bad_lines=False);#opening the file UScomments
# Out:
# b'Skipping line 113225: expected 4 fields, saw 5\n'
# b'Skipping line 158379: expected 4 fields, saw 7\nSkipping line 241590: expected 4 fields, saw 5\nSkipping line 245637: expected 4 fields, saw 7\n'
# b'Skipping line 521402: expected 4 fields, saw 5\n'
#            video_id  \
# 0       jt2OHQh0HoQ
# 1       jt2OHQh0HoQ
# 2       jt2OHQh0HoQ
# 3       jt2OHQh0HoQ
# 4       jt2OHQh0HoQ
# ...             ...
# 718447  lLN1FwiqGwc
# 718448  lLN1FwiqGwc
# 718449  lLN1FwiqGwc
# 718450  lLN1FwiqGwc
# 718451  lLN1FwiqGwc
#
#                                                                                                             comment_text  \
# 0                    It's more accurate to call it the M+ (1000) because the price is closer than calling it the X (10).
# 1                                                                                  To be there with a samsung phone\n😂😂😂
# ...

# %%
comm = comm.drop(columns = ['video_id', 'likes', 'replies'])

# %%
def unique(list1): 
  
    # intilize a null list 
    unique_list = [] 
      
    # traverse for all elements 
    for x in list1: 
        # check if exists in unique_list or not 
        if x not in unique_list: 
            unique_list.append(x) 
    # print list 
    for x in unique_list: 
        print(x),

# %%
comm.shape
# Out:
# (718452, 1)

# %%
data = comm

# %%
pol=[] # list which will contain the polarity of the comments
for i in data['comment_text']:
    try:
        analysis =TextBlob(i)
        pol.append(analysis.sentiment.polarity)
        
    except:
        pol.append(0)

# %%
data['pol']=pol
# Out:
# 0.45000000000000007
# 0.0
# 1.0
# 0.30000000000000004
# -0.10000000000000003
# 0.028571428571428564
# 0.5
# 0.026562500000000003
# 0.2
# 0.25
# 0.3
# 0.1
# 0.26684220251293417
# 0.37878787878787873
# 0.6000000000000001
# 0.7
# 0.4333333333333333
# -0.5
# 0.6
# -0.4
# -0.2
# 0.05
# -0.78125
# 0.04999999999999999
# 0.16666666666666666
# -0.05
# -0.125
# 0.26
# -0.01171875
# -0.175
# 0.13636363636363635
# 0.5444444444444444
# 0.35833333333333334
# -0.13333333333333333
# 0.65
# -0.3125
# 0.15277777777777776
# -0.0625
# -0.1
# 0.4166666666666667
# 0.4
# 0.10000000000000002
# 0.26666666666666666
# 0.3125
# 0.625
# 0.17500000000000004
# 0.32499999999999996
# 0.109375
# -0.4777777777777778
# 0.1625
# -0.25
# -0.08333333333333333
# -0.08750000000000001
# -0.26666666666666666
# -0.065
# 0.10416666666666666
# 0.75
# 0.7500000000000001
# 0.8
# 0.425
# 0.9
# 0.26785714285714285
# -0.075
# 0.43333333333333335
# 0.55
# -0.08
# -0.1413888888888889
# -0.07500000000000001
# 0.2375
# -0.75
# ...

# %%
data['pol'][data['pol'] > 0] = 1

# %%
data['pol'][data['pol'] < 0] = -1

# %%
data
# Out:
#                                                                                                             comment_text  \
# 0                    It's more accurate to call it the M+ (1000) because the price is closer than calling it the X (10).
# 1                                                                                  To be there with a samsung phone\n😂😂😂
# 2                           Thank gosh, a place I can watch it without having to be at HD... my speed doesn’t support HD
# 3                             What happened to the home button on the iPhone X? *****Cough****copying Samsung******cough
# 4       Power is the disease.  Care is the cure.  Keep caring for yourself and others as best as you can.  This is life.
# ...                                                                                                                  ...
# 718447                                                                                           MEME ME MEME ME MEME ME
# ...

# %%
data.to_csv('FinalDataset.csv')

# %%
data['pol'][data['pol'] == 1].count()
# Out:
# 327282

# %%
data['pol'][data['pol'] == -1].count()
# Out:
# 104887

# %%
data['pol'][data['pol'] == 0].count()
# Out:
# 286283
